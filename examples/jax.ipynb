# %%
import jax

from illia.distributions.jax.gaussian import GaussianDistribution

# %%
distribution = GaussianDistribution((30, 30))
input_key = jax.random.key(0)
params = distribution.init(input_key)

# %%
distribution.apply(params)
# Out:
# Array([[ 2.29571126e-02,  1.55567214e-01,  9.90005314e-01,
#         -1.62390280e+00,  5.19036576e-02, -3.24514836e-01,
#         -5.29793650e-02,  1.14343381e+00, -5.23035169e-01,
#         -7.15808392e-01,  2.18173727e-01, -3.31481218e-01,
#          7.05017686e-01,  3.91094893e-01,  3.72626245e-01,
#         -9.01466236e-03, -1.25983763e+00,  2.62339258e+00,
#         -4.99259502e-01,  3.78961712e-01,  7.51592368e-02,
#         -5.32320261e-01, -3.66714686e-01,  9.16092575e-01,
#         -6.74495280e-01, -1.03421915e+00, -7.77541935e-01,
#         -1.22184627e-01,  3.71749729e-01, -1.16818964e+00],
#        [-1.06548123e-01,  2.70514190e-02, -3.55230927e-01,
#         -6.50441289e-01,  2.41189986e-01,  2.87925065e-01,
#         -2.54333615e-01, -1.29712760e+00, -6.99048415e-02,
#         -4.51303273e-01, -1.19317979e-01,  1.10337943e-01,
#         -2.43837491e-01,  9.39987361e-01,  3.10618937e-01,
#          1.24725056e+00,  3.38057697e-01,  9.21270430e-01,
# ...

# %%
distribution.apply(params, method="log_prob")
# Out:
# Array(18448.656, dtype=float32)

# %%
params["params"].keys()
# Out:
# dict_keys(['mu', 'rho'])
